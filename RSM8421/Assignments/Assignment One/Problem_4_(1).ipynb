# %% [markdown]
# <a href="https://colab.research.google.com/github/KeqingW44448/api/blob/main/RSM8421/Assignments/Assignment%20One/Problem_4_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview
# This assignment consists of several exercises focused on **debugging neural networks**. Each network provided contains at least one issue. Your task is to identify the problem, explain your reasoning, and apply the appropriate debugging techniques you have learned in class to resolve it.

# %%
from tensorflow import keras
import numpy as np

from keras.models import Sequential
from keras.layers import Input, Dense, Activation
from keras.datasets import mnist
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.callbacks import TensorBoard
from keras.datasets import boston_housing
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Exercise 4

# %%
# Load the dataset
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

print("Training Dataset Size: ", x_train.shape)
print("Training Labels Size: ", y_train.shape)
print("Testing Dataset Size: ", x_test.shape)
print("Testing Labels Size: ", y_test.shape)

model1 = Sequential()
model1.add(Input(shape=(13,)))
model1.add(Dense(15, activation="relu"))
model1.add(Dense(15, activation="relu"))
model1.add(Dense(15, activation="relu"))
model1.add(Dense(1, activation="relu"))

model1.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training Dataset Size:  (404, 13)
# Training Labels Size:  (404,)
# Testing Dataset Size:  (102, 13)
# Testing Labels Size:  (102,)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 15)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            16 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 706 (2.76 KB)
#  Trainable params: 706 (2.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model1.compile(loss='mape', optimizer=Adam(learning_rate=0.01))
callbacks = [
    TensorBoard(log_dir='./log/exercise4', histogram_freq=1),
]
history = model1.fit(x_train, y_train, batch_size=10, epochs=20, validation_split=0.15,
                     callbacks=callbacks)
# Out:
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 95.7999 - val_loss: 34.8804
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.9369 - val_loss: 20.0478
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.1342 - val_loss: 16.8201
# Epoch 4/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 14.5251 - val_loss: 13.3444
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13.8184 - val_loss: 11.6511
# Epoch 6/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.6961 - val_loss: 11.8360
# Epoch 7/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.4276 - val_loss: 10.7445
# Epoch 8/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.2636 - val_loss: 10.8554
# Epoch 9/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.4474 - val_loss: 11.0219
# Epoch 10/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.8719 - val_loss: 10.6222
# Epoch 11/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.2571 - val_loss: 11.6077
# Epoch 12/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.6717 - val_loss: 11.8839
# Epoch 13/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.0041 - val_loss: 11.1355
# Epoch 14/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.8152 - val_loss: 9.7861
# Epoch 15/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.8055 - val_loss: 10.0317
# Epoch 16/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.0384 - val_loss: 10.3346
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2971 - val_loss: 11.0630
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.0227 - val_loss: 11.4569
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2356 - val_loss: 10.2343
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.0160 - val_loss: 10.1220

# %%
model1.evaluate(x_test, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.5333
# 13.838327407836914

# %% [markdown]
# ## Problem 4
#
# The model's loss remains high, and its performance is unsatisfactory. Why is this happening? (Recall that in the warm-up exercise `2.2 A First Feedforward Neural Network - Solved.ipynb`, we were able to achieve a test MAE of around \$2–3K.) What general lesson can you take from this example?
#
# Use **TensorBoard** to help debug the issue, if applicable.

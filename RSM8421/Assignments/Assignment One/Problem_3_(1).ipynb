# %% [markdown]
# <a href="https://colab.research.google.com/github/KeqingW44448/api/blob/main/RSM8421/Assignments/Assignment%20One/Problem_3_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview
# This assignment consists of several exercises focused on **debugging neural networks**. Each network provided contains at least one issue. Your task is to identify the problem, explain your reasoning, and apply the appropriate debugging techniques you have learned in class to resolve it.

# %%
from tensorflow import keras
import numpy as np

from keras.models import Sequential
from keras.layers import Input, Dense, Activation
from keras.datasets import mnist
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.callbacks import TensorBoard
from keras.datasets import boston_housing
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Exercise 3

# %%
# Load the dataset
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

print("Training Dataset Size: ", x_train.shape)
print("Training Labels Size: ", y_train.shape)
print("Testing Dataset Size: ", x_test.shape)
print("Testing Labels Size: ", y_test.shape)

model1 = Sequential()
model1.add(Input(shape=(13,)))
model1.add(Dense(15, activation="relu"))
model1.add(Dense(15, activation="relu"))
model1.add(Dense(15, activation="relu"))
model1.add(Dense(1, activation="sigmoid"))

model1.summary()
# Out:
# Training Dataset Size:  (404, 13)
# Training Labels Size:  (404,)
# Testing Dataset Size:  (102, 13)
# Testing Labels Size:  (102,)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 15)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            16 │
# ...

# %%
model1.compile(loss='mae', optimizer=Adam(learning_rate=0.01))
callbacks = [
    TensorBoard(log_dir='./exercise3', histogram_freq=1),
]
history = model1.fit(x_train, y_train, batch_size=10, epochs=20, validation_split=0.15,
                     callbacks=callbacks)


# The epochs from 20 to 1000, improve the accuracy, however, using Sigmoid function will stuck in the error, (0,1)
# Out:
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 21.6037 - val_loss: 23.0131
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.4179 - val_loss: 23.0131
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.7939 - val_loss: 23.0131
# Epoch 4/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.5554 - val_loss: 23.0131
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.4005 - val_loss: 23.0131
# Epoch 6/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.3838 - val_loss: 23.0131
# Epoch 7/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.1764 - val_loss: 23.0131
# Epoch 8/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.7797 - val_loss: 23.0131
# Epoch 9/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.9192 - val_loss: 23.0131
# Epoch 10/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.3401 - val_loss: 23.0131
# Epoch 11/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.8027 - val_loss: 23.0131
# ...

# %%
model1.evaluate(x_test, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 21.5703
# 22.078432083129883

# %% [markdown]
# ## Problem 3
#
# The model's loss remains high, and its performance is unsatisfactory. Why is this happening? (Recall that in the warm-up exercise `2.2 A First Feedforward Neural Network - Solved.ipynb`, we were able to achieve a test MAE of around \$2–3K.) What general lesson can you take from this example?
#
# Use **TensorBoard** to help debug the issue, if applicable.

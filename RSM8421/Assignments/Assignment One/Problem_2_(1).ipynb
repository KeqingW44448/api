# %% [markdown]
# <a href="https://colab.research.google.com/github/KeqingW44448/api/blob/main/RSM8421/Assignments/Assignment%20One/Problem_2_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview
# This assignment consists of several exercises focused on **debugging neural networks**. Each network provided contains at least one issue. Your task is to identify the problem, explain your reasoning, and apply the appropriate debugging techniques you have learned in class to resolve it.

# %%
from tensorflow import keras
import numpy as np

from keras.models import Sequential
from keras.layers import Input, Dense, Activation
from keras.datasets import mnist
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.callbacks import TensorBoard
from keras.datasets import boston_housing
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Exercise 2

# %%
# Load the dataset
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

print("Training Dataset Size: ", x_train.shape)
print("Training Labels Size: ", y_train.shape)
print("Testing Dataset Size: ", x_test.shape)
print("Testing Labels Size: ", y_test.shape)

model1 = Sequential()
model1.add(Input(shape=(13,)))
model1.add(Dense(15, activation="relu"))
model1.add(Dense(15, activation="relu"))
model1.add(Dense(15, activation="relu"))
model1.add(Dense(1))

model1.summary()
# Out:
# ...
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Training Dataset Size:  (404, 13)
# Training Labels Size:  (404,)
# Testing Dataset Size:  (102, 13)
# Testing Labels Size:  (102,)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 15)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            16 │
# ...

# %%
model1.compile(loss='mae', optimizer=Adam(learning_rate=0.0001))
callbacks = [
    TensorBoard(log_dir='./exercise2', histogram_freq=1),
]
history = model1.fit(x_train, y_train, batch_size=10, epochs=20, validation_split=0.15,
                     callbacks=callbacks)
# Out:
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 21.8546 - val_loss: 23.8824
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.1341 - val_loss: 23.8387
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.5291 - val_loss: 23.7882
# Epoch 4/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.9433 - val_loss: 23.7328
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.9438 - val_loss: 23.6688
# Epoch 6/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.7250 - val_loss: 23.5963
# Epoch 7/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.0433 - val_loss: 23.5114
# Epoch 8/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.4134 - val_loss: 23.4181
# Epoch 9/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.3646 - val_loss: 23.3138
# Epoch 10/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.4653 - val_loss: 23.1983
# Epoch 11/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.6867 - val_loss: 23.0710
# ...

# %%
model1.evaluate(x_test, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.5080
# 20.016948699951172

# %% [markdown]
# ## Problem 2
#
# The model's loss is high, and its performance is poor. Why is this happening? (Remember that in the warm-up exercise `2.2 A First Feedforward Neural Network - Solved.ipynb`, we were able to achieve a test MAE of about \$2–3K.) What general lesson can you take away from this example?
#
# Use **TensorBoard** to assist in debugging, if applicable.
